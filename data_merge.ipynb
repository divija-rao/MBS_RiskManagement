# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Adding headers

# %%
origination_headers = [
    'Credit Score',
    'First Payment Date',
    'First Time Homebuyer Flag',
    'Maturity Date',
    'Metropolitan Statistical Area (MSA) Or Metropolitan Division',
    'Mortgage Insurance Percentage (MI %)',
    'Number of Units',
    'Occupancy Status',
    'Original Combined Loan-to-Value (CLTV)',
    'Original Debt-to-Income (DTI) Ratio',
    'Original UPB',
    'Original Loan-to-Value (LTV)',
    'Original Interest Rate',
    'Channel',
    'Prepayment Penalty Mortgage (PPM) Flag',
    'Amortization Type (Formerly Product Type)',
    'Property State',
    'Property Type',
    'Postal Code',
    'Loan Sequence Number',
    'Loan Purpose',
    'Original Loan Term',
    'Number of Borrowers',
    'Seller Name',
    'Servicer Name',
    'Super Conforming Flag',
    'Pre-HARP Loan Sequence Number',
    'Program Indicator',
    'HARP Indicator',
    'Property Valuation Method',
    'Interest Only (I/O) Indicator',
    'Mortgage Insurance Cancellation Indicator'
]

# %%
d14o = pd.read_csv("/Users/ishawadekar/Downloads/mbs/MBS_RiskManagement/new/mbs_sample_data/sample_orig_2014.txt", delimiter='|', header=None)
d14o.columns = origination_headers
d14o.head()
# Out:
# /var/folders/92/990hzl6x4976tsbn7vr209sm0000gn/T/ipykernel_16608/459732964.py:1: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   d14o = pd.read_csv("/Users/ishawadekar/Downloads/mbs/MBS_RiskManagement/new/mbs_sample_data/sample_orig_2014.txt", delimiter='|', header=None)
#    Credit Score  First Payment Date First Time Homebuyer Flag  Maturity Date  \
# 0           794              201403                         N         202902
# 1           740              201405                         N         204404
# 2           638              201403                         N         203402
# 3           786              201404                         N         202903
# 4           732              201403                         N         204402
#
#    Metropolitan Statistical Area (MSA) Or Metropolitan Division  \
# 0                                            30700.0
# 1                                            41620.0
# ...

# %%
d15o = pd.read_csv("/Users/ishawadekar/Downloads/mbs/MBS_RiskManagement/new/mbs_sample_data/sample_orig_2015.txt", delimiter='|', header=None)
d15o.columns = origination_headers
d15o.head()
# Out:
#    Credit Score  First Payment Date First Time Homebuyer Flag  Maturity Date  \
# 0           734              201504                         N         203003
# 1           797              201504                         N         204503
# 2           670              201504                         N         203003
# 3           731              201503                         N         204502
# 4           668              201504                         N         203003
#
#    Metropolitan Statistical Area (MSA) Or Metropolitan Division  \
# 0                                                NaN
# 1                                                NaN
# 2                                            11460.0
# 3                                                NaN
# 4                                            39340.0
#
#    Mortgage Insurance Percentage (MI %)  Number of Units Occupancy Status  \
# 0                                     0                1                P
# ...

# %%
d16o = pd.read_csv("/Users/ishawadekar/Downloads/mbs/MBS_RiskManagement/new/mbs_sample_data/sample_orig_2016.txt", delimiter='|', header=None)
d16o.columns = origination_headers
d16o.head()
# Out:
#    Credit Score  First Payment Date First Time Homebuyer Flag  Maturity Date  \
# 0           686              201604                         N         203603
# 1           774              201603                         Y         204602
# 2           808              201604                         N         203103
# 3           784              201603                         N         204602
# 4           798              201603                         N         204602
#
#    Metropolitan Statistical Area (MSA) Or Metropolitan Division  \
# 0                                            39820.0
# 1                                            29620.0
# 2                                            30700.0
# 3                                                NaN
# 4                                            47664.0
#
#    Mortgage Insurance Percentage (MI %)  Number of Units Occupancy Status  \
# 0                                     0                1                P
# ...

# %%
d17o = pd.read_csv("/Users/ishawadekar/Downloads/mbs/MBS_RiskManagement/new/mbs_sample_data/sample_orig_2017.txt", delimiter='|', header=None)
d17o.columns = origination_headers
d17o.head()
# Out:
#    Credit Score  First Payment Date First Time Homebuyer Flag  Maturity Date  \
# 0           809              201705                         N         204704
# 1           702              201703                         N         203202
# 2           792              201703                         N         204702
# 3           776              201703                         N         204702
# 4           790              201703                         N         204702
#
#    Metropolitan Statistical Area (MSA) Or Metropolitan Division  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                            41620.0
#
#    Mortgage Insurance Percentage (MI %)  Number of Units Occupancy Status  \
# 0                                     0                1                P
# ...

# %%
d18o = pd.read_csv("/Users/ishawadekar/Downloads/mbs/MBS_RiskManagement/new/mbs_sample_data/sample_orig_2018.txt", delimiter='|', header=None)
d18o.columns = origination_headers
d18o.head()
# Out:
#    Credit Score  First Payment Date First Time Homebuyer Flag  Maturity Date  \
# 0           654              201803                         N         204802
# 1           693              201803                         N         203302
# 2           757              201803                         Y         204802
# 3           807              201803                         N         203302
# 4           812              201803                         N         203302
#
#    Metropolitan Statistical Area (MSA) Or Metropolitan Division  \
# 0                                                NaN
# 1                                            24340.0
# 2                                                NaN
# 3                                                NaN
# 4                                            19340.0
#
#    Mortgage Insurance Percentage (MI %)  Number of Units Occupancy Status  \
# 0                                     0                1                P
# ...

# %%
d19o = pd.read_csv("/Users/ishawadekar/Downloads/mbs/MBS_RiskManagement/new/mbs_sample_data/sample_orig_2019.txt", delimiter='|', header=None)
d19o.columns = origination_headers
d19o.head()
# Out:
# /var/folders/92/990hzl6x4976tsbn7vr209sm0000gn/T/ipykernel_16608/4020388378.py:1: DtypeWarning: Columns (26,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   d19o = pd.read_csv("/Users/ishawadekar/Downloads/mbs/MBS_RiskManagement/new/mbs_sample_data/sample_orig_2019.txt", delimiter='|', header=None)
#    Credit Score  First Payment Date First Time Homebuyer Flag  Maturity Date  \
# 0           741              201903                         N         204902
# 1           731              201903                         N         204902
# 2           722              201903                         N         204902
# 3           729              201903                         N         204902
# 4           773              201903                         N         204902
#
#    Metropolitan Statistical Area (MSA) Or Metropolitan Division  \
# 0                                                NaN
# 1                                            13460.0
# ...

# %%
d20o = pd.read_csv("/Users/ishawadekar/Downloads/mbs/MBS_RiskManagement/new/mbs_sample_data/sample_orig_2020.txt", delimiter='|', header=None)
d20o.columns = origination_headers
d20o.head()
# Out:
#    Credit Score  First Payment Date First Time Homebuyer Flag  Maturity Date  \
# 0           714              202003                         Y         205002
# 1           710              202003                         N         204002
# 2           790              202003                         N         205002
# 3           744              202003                         N         203502
# 4           618              202003                         N         205002
#
#    Metropolitan Statistical Area (MSA) Or Metropolitan Division  \
# 0                                            14454.0
# 1                                            45820.0
# 2                                            38900.0
# 3                                                NaN
# 4                                                NaN
#
#    Mortgage Insurance Percentage (MI %)  Number of Units Occupancy Status  \
# 0                                     0                1                P
# ...

# %%
d21o = pd.read_csv("/Users/ishawadekar/Downloads/mbs/MBS_RiskManagement/new/mbs_sample_data/sample_orig_2021.txt", delimiter='|', header=None)
d21o.columns = origination_headers
d21o.head()
# Out:
#    Credit Score  First Payment Date First Time Homebuyer Flag  Maturity Date  \
# 0           776              202103                         N         205102
# 1           746              202103                         N         205102
# 2           710              202103                         N         204102
# 3           722              202103                         N         205102
# 4           761              202103                         N         205102
#
#    Metropolitan Statistical Area (MSA) Or Metropolitan Division  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                            16984.0
# 4                                            29020.0
#
#    Mortgage Insurance Percentage (MI %)  Number of Units Occupancy Status  \
# 0                                     0                1                P
# ...

# %%
d22o = pd.read_csv("/Users/ishawadekar/Downloads/mbs/MBS_RiskManagement/new/mbs_sample_data/sample_orig_2022.txt", delimiter='|', header=None)
d22o.columns = origination_headers
d22o.head()
# Out:
#    Credit Score  First Payment Date First Time Homebuyer Flag  Maturity Date  \
# 0           768              202203                         N         203702
# 1           781              202203                         N         205202
# 2           809              202204                         N         204203
# 3           661              202203                         N         205202
# 4           668              202203                         Y         205202
#
#    Metropolitan Statistical Area (MSA) Or Metropolitan Division  \
# 0                                                NaN
# 1                                                NaN
# 2                                            36540.0
# 3                                            26900.0
# 4                                            36540.0
#
#    Mortgage Insurance Percentage (MI %)  Number of Units Occupancy Status  \
# 0                                     0                1                P
# ...

# %%
d23o = pd.read_csv("/Users/ishawadekar/Downloads/mbs/MBS_RiskManagement/new/mbs_sample_data/sample_orig_2023.txt", delimiter='|', header=None)
d23o.columns = origination_headers
d23o.head()
# Out:
#    Credit Score  First Payment Date First Time Homebuyer Flag  Maturity Date  \
# 0           794              202305                         N         204304
# 1           775              202303                         N         205302
# 2           651              202303                         N         205302
# 3           721              202304                         N         205303
# 4           702              202303                         Y         205302
#
#    Metropolitan Statistical Area (MSA) Or Metropolitan Division  \
# 0                                            45220.0
# 1                                            41180.0
# 2                                            16580.0
# 3                                            41180.0
# 4                                                NaN
#
#    Mortgage Insurance Percentage (MI %)  Number of Units Occupancy Status  \
# 0                                     0                1                I
# ...

# %%
d24o = pd.read_csv("/Users/ishawadekar/Downloads/mbs/MBS_RiskManagement/new/mbs_sample_data/sample_orig_2024.txt", delimiter='|', header=None)
d24o.columns = origination_headers
d24o.head()
# Out:
#    Credit Score  First Payment Date First Time Homebuyer Flag  Maturity Date  \
# 0           812              202403                         N         205402
# 1           797              202403                         N         205402
# 2           775              202403                         N         203902
# 3           768              202403                         N         205402
# 4           776              202403                         N         205402
#
#    Metropolitan Statistical Area (MSA) Or Metropolitan Division  \
# 0                                            16984.0
# 1                                                NaN
# 2                                            30700.0
# 3                                            45820.0
# 4                                            43100.0
#
#    Mortgage Insurance Percentage (MI %)  Number of Units Occupancy Status  \
# 0                                     0                1                P
# ...

# %%
performance_headers = [
    'Loan Sequence Number',
    'Monthly Reporting Period',
    'Current Actual UPB',
    'Current Loan Delinquency Status',
    'Loan Age',
    'Remaining Months to Legal Maturity',
    'Defect Settlement Date',
    'Modification Flag',
    'Zero Balance Code',
    'Zero Balance Effective Date',
    'Current Interest Rate',
    'Current Deferred UPB',
    'Due Date of Last Paid Installment (DDLPI)',
    'MI Recoveries',
    'Net Sales Proceeds',
    'Non MI Recoveries',
    'Expenses',
    'Legal Costs',
    'Maintenance and Preservation Costs',
    'Taxes and Insurance',
    'Miscellaneous Expenses',
    'Actual Loss Calculation',
    'Modification Cost',
    'Step Modification Flag',
    'Deferred Payment Plan',
    'Estimated Loan-to-Value (ELTV)',
    'Zero Balance Removal UPB',
    'Delinquent Accrued Interest',
    'Delinquency Due to Disaster',
    'Borrower Assistance Status Code',
    'Current Month Modification Cost',
    'Interest Bearing UPB'
]

# %%
d14 = pd.read_csv("/Users/ishawadekar/Downloads/mbs/MBS_RiskManagement/new/mbs_sample_data/sample_svcg_2014.txt", delimiter='|', header=None)
d14.columns = performance_headers
d14.head()
# Out:
# /var/folders/92/990hzl6x4976tsbn7vr209sm0000gn/T/ipykernel_16608/4155928187.py:1: DtypeWarning: Columns (3,7,23,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   d14 = pd.read_csv("/Users/ishawadekar/Downloads/mbs/MBS_RiskManagement/new/mbs_sample_data/sample_svcg_2014.txt", delimiter='|', header=None)
#   Loan Sequence Number  Monthly Reporting Period  Current Actual UPB  \
# 0         F14Q10000011                    201402             62000.0
# 1         F14Q10000011                    201403             62000.0
# 2         F14Q10000011                    201404             62000.0
# 3         F14Q10000011                    201405             61000.0
# 4         F14Q10000011                    201406             61000.0
#
#   Current Loan Delinquency Status  Loan Age  \
# 0                               0         0
# 1                               0         1
# 2                               0         2
# ...

# %%
d15 = pd.read_csv("/Users/ishawadekar/Downloads/mbs/MBS_RiskManagement/new/mbs_sample_data/sample_svcg_2015.txt", delimiter='|', header=None)
d15.columns = performance_headers
d15.head()
# Out:
# /var/folders/92/990hzl6x4976tsbn7vr209sm0000gn/T/ipykernel_16608/1143964158.py:1: DtypeWarning: Columns (3,7,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   d15 = pd.read_csv("/Users/ishawadekar/Downloads/mbs/MBS_RiskManagement/new/mbs_sample_data/sample_svcg_2015.txt", delimiter='|', header=None)
#   Loan Sequence Number  Monthly Reporting Period  Current Actual UPB  \
# 0         F15Q10000025                    201503            417000.0
# 1         F15Q10000025                    201504            415000.0
# 2         F15Q10000025                    201505            413000.0
# 3         F15Q10000025                    201506            409000.0
# 4         F15Q10000025                    201507            409000.0
#
#   Current Loan Delinquency Status  Loan Age  \
# 0                               0         0
# 1                               0         1
# 2                               0         2
# 3                               0         3
# ...

# %%
d16 = pd.read_csv("/Users/ishawadekar/Downloads/mbs/MBS_RiskManagement/new/mbs_sample_data/sample_svcg_2016.txt", delimiter='|', header=None)
d16.columns = performance_headers
d16.head()
# Out:
# /var/folders/92/990hzl6x4976tsbn7vr209sm0000gn/T/ipykernel_16608/1631639891.py:1: DtypeWarning: Columns (3,7,23,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   d16 = pd.read_csv("/Users/ishawadekar/Downloads/mbs/MBS_RiskManagement/new/mbs_sample_data/sample_svcg_2016.txt", delimiter='|', header=None)
#   Loan Sequence Number  Monthly Reporting Period  Current Actual UPB  \
# 0         F16Q10000006                    201603            125000.0
# 1         F16Q10000006                    201604            124000.0
# 2         F16Q10000006                    201605            124000.0
# 3         F16Q10000006                    201606            124000.0
# 4         F16Q10000006                    201607            123000.0
#
#   Current Loan Delinquency Status  Loan Age  \
# 0                               0         0
# 1                               0         1
# 2                               0         2
# ...

# %%
d17 = pd.read_csv("/Users/ishawadekar/Downloads/mbs/MBS_RiskManagement/new/mbs_sample_data/sample_svcg_2017.txt", delimiter='|', header=None)
d17.columns = performance_headers
d17.head()
# Out:
# /var/folders/92/990hzl6x4976tsbn7vr209sm0000gn/T/ipykernel_16608/3143473958.py:1: DtypeWarning: Columns (3,7,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   d17 = pd.read_csv("/Users/ishawadekar/Downloads/mbs/MBS_RiskManagement/new/mbs_sample_data/sample_svcg_2017.txt", delimiter='|', header=None)
#   Loan Sequence Number  Monthly Reporting Period  Current Actual UPB  \
# 0         F17Q10000002                    201704            195000.0
# 1         F17Q10000002                    201705            194000.0
# 2         F17Q10000002                    201706            194000.0
# 3         F17Q10000002                    201707            194000.0
# 4         F17Q10000002                    201708            193000.0
#
#   Current Loan Delinquency Status  Loan Age  \
# 0                               0         0
# 1                               0         1
# 2                               0         2
# 3                               0         3
# ...

# %%
d18 = pd.read_csv("/Users/ishawadekar/Downloads/mbs/MBS_RiskManagement/new/mbs_sample_data/sample_svcg_2018.txt", delimiter='|', header=None)
d18.columns = performance_headers
d18.head()
# Out:
# /var/folders/92/990hzl6x4976tsbn7vr209sm0000gn/T/ipykernel_16608/2317314676.py:1: DtypeWarning: Columns (3,7,23,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   d18 = pd.read_csv("/Users/ishawadekar/Downloads/mbs/MBS_RiskManagement/new/mbs_sample_data/sample_svcg_2018.txt", delimiter='|', header=None)
#   Loan Sequence Number  Monthly Reporting Period  Current Actual UPB  \
# 0         F18Q10000028                    201802             50000.0
# 1         F18Q10000028                    201803             50000.0
# 2         F18Q10000028                    201804             50000.0
# 3         F18Q10000028                    201805             50000.0
# 4         F18Q10000028                    201806             50000.0
#
#   Current Loan Delinquency Status  Loan Age  \
# 0                               0         0
# 1                               0         1
# 2                               0         2
# ...

# %%
d19 = pd.read_csv("/Users/ishawadekar/Downloads/mbs/MBS_RiskManagement/new/mbs_sample_data/sample_svcg_2019.txt", delimiter='|', header=None)
d19.columns = performance_headers
d19.head()
# Out:
# /var/folders/92/990hzl6x4976tsbn7vr209sm0000gn/T/ipykernel_16608/963226266.py:1: DtypeWarning: Columns (3,7,23,24,28,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   d19 = pd.read_csv("/Users/ishawadekar/Downloads/mbs/MBS_RiskManagement/new/mbs_sample_data/sample_svcg_2019.txt", delimiter='|', header=None)
#   Loan Sequence Number  Monthly Reporting Period  Current Actual UPB  \
# 0         F19Q10000056                    201902            372000.0
# 1         F19Q10000056                    201903            372000.0
# 2         F19Q10000056                    201904            371000.0
# 3         F19Q10000056                    201905            370000.0
# 4         F19Q10000056                    201906            370000.0
#
#   Current Loan Delinquency Status  Loan Age  \
# 0                               0         0
# 1                               0         1
# 2                               0         2
# ...

# %%
d20 = pd.read_csv("/Users/ishawadekar/Downloads/mbs/MBS_RiskManagement/new/mbs_sample_data/sample_svcg_2020.txt", delimiter='|', header=None)
d20.columns = performance_headers
d20.head()
# Out:
# /var/folders/92/990hzl6x4976tsbn7vr209sm0000gn/T/ipykernel_16608/2613307140.py:1: DtypeWarning: Columns (3,7,23,24,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   d20 = pd.read_csv("/Users/ishawadekar/Downloads/mbs/MBS_RiskManagement/new/mbs_sample_data/sample_svcg_2020.txt", delimiter='|', header=None)
#   Loan Sequence Number  Monthly Reporting Period  Current Actual UPB  \
# 0         F20Q10000154                    202002            399000.0
# 1         F20Q10000154                    202003            399000.0
# 2         F20Q10000154                    202004            398000.0
# 3         F20Q10000154                    202005            398000.0
# 4         F20Q10000154                    202006            397000.0
#
#   Current Loan Delinquency Status  Loan Age  \
# 0                               0         0
# 1                               0         1
# 2                               0         2
# ...

# %%
d21 = pd.read_csv("/Users/ishawadekar/Downloads/mbs/MBS_RiskManagement/new/mbs_sample_data/sample_svcg_2021.txt", delimiter='|', header=None)
d21.columns = performance_headers
d21.head()
# Out:
# /var/folders/92/990hzl6x4976tsbn7vr209sm0000gn/T/ipykernel_16608/1868931122.py:1: DtypeWarning: Columns (3,7,23,24,28,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   d21 = pd.read_csv("/Users/ishawadekar/Downloads/mbs/MBS_RiskManagement/new/mbs_sample_data/sample_svcg_2021.txt", delimiter='|', header=None)
#   Loan Sequence Number  Monthly Reporting Period  Current Actual UPB  \
# 0         F21Q11275826                    202102             68000.0
# 1         F21Q11275826                    202103             68000.0
# 2         F21Q11275826                    202104             68000.0
# 3         F21Q11275826                    202105             68000.0
# 4         F21Q11275826                    202106             67000.0
#
#   Current Loan Delinquency Status  Loan Age  \
# 0                               0         0
# 1                               0         1
# 2                               0         2
# ...

# %%
d22 = pd.read_csv("/Users/ishawadekar/Downloads/mbs/MBS_RiskManagement/new/mbs_sample_data/sample_svcg_2022.txt", delimiter='|', header=None)
d22.columns = performance_headers
d22.head()
# Out:
# /var/folders/92/990hzl6x4976tsbn7vr209sm0000gn/T/ipykernel_16608/2794957401.py:1: DtypeWarning: Columns (3,7,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   d22 = pd.read_csv("/Users/ishawadekar/Downloads/mbs/MBS_RiskManagement/new/mbs_sample_data/sample_svcg_2022.txt", delimiter='|', header=None)
#   Loan Sequence Number  Monthly Reporting Period  Current Actual UPB  \
# 0         F22Q10000012                    202202             95000.0
# 1         F22Q10000012                    202203             94000.0
# 2         F22Q10000012                    202204             94000.0
# 3         F22Q10000012                    202205             93000.0
# 4         F22Q10000012                    202206             93000.0
#
#   Current Loan Delinquency Status  Loan Age  \
# 0                               0         0
# 1                               0         1
# 2                               0         2
# 3                               0         3
# ...

# %%
d23 = pd.read_csv("/Users/ishawadekar/Downloads/mbs/MBS_RiskManagement/new/mbs_sample_data/sample_svcg_2023.txt", delimiter='|', header=None)
d23.columns = performance_headers
d23.head()
# Out:
# /var/folders/92/990hzl6x4976tsbn7vr209sm0000gn/T/ipykernel_16608/2502974010.py:1: DtypeWarning: Columns (3,7,23,24,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   d23 = pd.read_csv("/Users/ishawadekar/Downloads/mbs/MBS_RiskManagement/new/mbs_sample_data/sample_svcg_2023.txt", delimiter='|', header=None)
#   Loan Sequence Number  Monthly Reporting Period  Current Actual UPB  \
# 0         F23Q10000001                    202304            104000.0
# 1         F23Q10000001                    202305            104000.0
# 2         F23Q10000001                    202306            103000.0
# 3         F23Q10000001                    202307            100000.0
# 4         F23Q10000001                    202308             99000.0
#
#   Current Loan Delinquency Status  Loan Age  \
# 0                               0         0
# 1                               0         1
# 2                               0         2
# ...

# %%
d24 = pd.read_csv("/Users/ishawadekar/Downloads/mbs/MBS_RiskManagement/new/mbs_sample_data/sample_svcg_2024.txt", delimiter='|', header=None)
d24.columns = performance_headers
d24.head()
# Out:
# /var/folders/92/990hzl6x4976tsbn7vr209sm0000gn/T/ipykernel_16608/3724074346.py:1: DtypeWarning: Columns (3,7,23,24,28,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   d24 = pd.read_csv("/Users/ishawadekar/Downloads/mbs/MBS_RiskManagement/new/mbs_sample_data/sample_svcg_2024.txt", delimiter='|', header=None)
#   Loan Sequence Number  Monthly Reporting Period  Current Actual UPB  \
# 0         F24Q10000019                    202402            246000.0
# 1         F24Q10000019                    202403            245000.0
# 2         F24Q10000019                    202404            245000.0
# 3         F24Q10000019                    202405            245000.0
# 4         F24Q10000019                    202406            244000.0
#
#   Current Loan Delinquency Status  Loan Age  \
# 0                               0         0
# 1                               0         1
# 2                               0         2
# ...

# %% [markdown]
# # Merging all origination and performance files

# %%
# List all DataFrames you want to merge vertically
all_origination_dfs = [d14o, d15o, d16o, d17o, d18o, d19o, d20o, d21o, d22o, d23o, d24o]

# Concatenate them into a single master DataFrame
# ignore_index=True ensures the final DataFrame has a clean, continuous index
df_orig_master = pd.concat(all_origination_dfs, ignore_index=True)

print("Vertical merge complete. Final DataFrame is df_perf_master.")
print(f"Total rows in master performance file: {df_orig_master.shape[0]:,}")
df_orig_master.head()
# Out:
# Vertical merge complete. Final DataFrame is df_perf_master.
# Total rows in master performance file: 550,000
#    Credit Score  First Payment Date First Time Homebuyer Flag  Maturity Date  \
# 0           794              201403                         N         202902
# 1           740              201405                         N         204404
# 2           638              201403                         N         203402
# 3           786              201404                         N         202903
# 4           732              201403                         N         204402
#
#    Metropolitan Statistical Area (MSA) Or Metropolitan Division  \
# 0                                            30700.0
# 1                                            41620.0
# 2                                            19780.0
# 3                                            38300.0
# 4                                            12060.0
#
# ...

# %%
# List all DataFrames you want to merge vertically
all_performance_dfs = [d14, d15, d16, d17, d18, d19, d20, d21, d22, d23, d24]

# Concatenate them into a single master DataFrame
# ignore_index=True ensures the final DataFrame has a clean, continuous index
df_perf_master = pd.concat(all_performance_dfs, ignore_index=True)

print("Vertical merge complete. Final DataFrame is df_perf_master.")
print(f"Total rows in master performance file: {df_perf_master.shape[0]:,}")
print(df_perf_master.head())
# Out:
# Vertical merge complete. Final DataFrame is df_perf_master.
# Total rows in master performance file: 23,248,344
#   Loan Sequence Number  Monthly Reporting Period  Current Actual UPB  \
# 0         F14Q10000011                    201402             62000.0
# 1         F14Q10000011                    201403             62000.0
# 2         F14Q10000011                    201404             62000.0
# 3         F14Q10000011                    201405             61000.0
# 4         F14Q10000011                    201406             61000.0
#
#   Current Loan Delinquency Status  Loan Age  \
# 0                               0         0
# 1                               0         1
# 2                               0         2
# 3                               0         3
# 4                               0         4
#
#    Remaining Months to Legal Maturity  Defect Settlement Date  \
# 0                                 180                     NaN
# ...

# %% [markdown]
# # Joining origination and performance files

# %%
# Ensure columns exist and clean names (this is crucial for merge success)
if 'Loan Sequence Number' in df_orig_master.columns:
    df_orig_master.columns = df_orig_master.columns.str.strip()
    df_orig_master.rename(columns={'Loan Sequence Number': 'Loan_ID'}, inplace=True)
elif 'Loan_ID' in df_orig_master.columns:
    df_orig_master.columns = df_orig_master.columns.str.strip()
    
if 'Loan Sequence Number' in df_perf_master.columns:
    df_perf_master.columns = df_perf_master.columns.str.strip()
    df_perf_master.rename(columns={'Loan Sequence Number': 'Loan_ID'}, inplace=True)
elif 'Loan_ID' in df_perf_master.columns:
    df_perf_master.columns = df_perf_master.columns.str.strip()


# --- 2. Perform the Horizontal Merge (Left Join) ---
# Target: df_perf_master (the large file with all monthly rows)
# Source: df_orig_master (the small file with unique loan data)
df_master_merged = df_perf_master.merge(
    df_orig_master, 
    on='Loan_ID', 
    how='left',
    suffixes=('_perf', '_orig') # Ensures clear naming if columns conflict
)

# --- 3. Verification ---
print("Horizontal Merge Complete.")
print(f"Final Master Data Shape (Rows, Columns): {df_master_merged.shape}")
print("\nVerifying merge success (static data must be repeated for each month):")

# Display a single loan's history to confirm the static data (Credit Score) is repeated
# and the dynamic data (Loan Age) changes.
verification_cols = ['Loan_ID', 'Loan Age', 'Monthly Reporting Period', 'Credit Score', 'Original UPB']
print(df_master_merged[verification_cols].head(10))
# Out:
# Horizontal Merge Complete.
# Final Master Data Shape (Rows, Columns): (23248344, 63)
#
# Verifying merge success (static data must be repeated for each month):
#         Loan_ID  Loan Age  Monthly Reporting Period  Credit Score  \
# 0  F14Q10000011         0                    201402           794
# 1  F14Q10000011         1                    201403           794
# 2  F14Q10000011         2                    201404           794
# 3  F14Q10000011         3                    201405           794
# 4  F14Q10000011         4                    201406           794
# 5  F14Q10000011         5                    201407           794
# 6  F14Q10000011         6                    201408           794
# 7  F14Q10000011         7                    201409           794
# 8  F14Q10000011         8                    201410           794
# 9  F14Q10000011         9                    201411           794
#
#    Original UPB
# 0         62000
# 1         62000
# 2         62000
# ...

# %% [markdown]
# # Saving Final Merged File

# %%
# Save the DataFrame to a CSV file
df_master_merged.to_csv(
    'final_master_loan_data.csv', 
    index=False,               # CRITICAL: Do NOT save the pandas row index as a column
    encoding='utf-8'           # Standard encoding for compatibility
)

print("File saved successfully as 'final_master_loan_data.csv' in the current directory. ✅")
# Out:
# File saved successfully as 'final_master_loan_data.csv' in the current directory. ✅

# %%
df_master_merged.shape
# Out:
# (23248344, 63)

# %%
columns_to_retain = [
    'Loan_ID',                                  # Renamed Unique Key
    'Credit Score',
    'First Payment Date',
    'Maturity Date',
    'Occupancy Status',
    'Original Combined Loan-to-Value (CLTV)',
    'Original Debt-to-Income (DTI) Ratio',
    'Original UPB',
    'Original Loan Term',
    'Monthly Reporting Period',
    'Current Actual UPB',
    'Current Loan Delinquency Status',
    'Loan Age',
    'Current Interest Rate',
    'Estimated Loan-to-Value (ELTV)'
]

# Select only the specified columns and save the result to a new DataFrame
df_final_cph = df_master_merged[columns_to_retain]

print("DataFrame successfully filtered.")
print(f"Final CPH Data Shape (Rows, Columns): {df_final_cph.shape}")
df_final_cph.head()
# Out:
# DataFrame successfully filtered.
# Final CPH Data Shape (Rows, Columns): (23248344, 15)
#         Loan_ID  Credit Score  First Payment Date  Maturity Date  \
# 0  F14Q10000011           794              201403         202902
# 1  F14Q10000011           794              201403         202902
# 2  F14Q10000011           794              201403         202902
# 3  F14Q10000011           794              201403         202902
# 4  F14Q10000011           794              201403         202902
#
#   Occupancy Status  Original Combined Loan-to-Value (CLTV)  \
# 0                I                                      73
# 1                I                                      73
# 2                I                                      73
# 3                I                                      73
# 4                I                                      73
#
#    Original Debt-to-Income (DTI) Ratio  Original UPB  Original Loan Term  \
# ...

# %%
single_loan_df = df_final_cph[df_final_cph['Loan_ID'] == 'F14Q10000011']
single_loan_df
# Out:
#          Loan_ID  Credit Score  First Payment Date  Maturity Date  \
# 0   F14Q10000011           794              201403         202902
# 1   F14Q10000011           794              201403         202902
# 2   F14Q10000011           794              201403         202902
# 3   F14Q10000011           794              201403         202902
# 4   F14Q10000011           794              201403         202902
# ..           ...           ...                 ...            ...
# 72  F14Q10000011           794              201403         202902
# 73  F14Q10000011           794              201403         202902
# 74  F14Q10000011           794              201403         202902
# 75  F14Q10000011           794              201403         202902
# 76  F14Q10000011           794              201403         202902
#
#    Occupancy Status  Original Combined Loan-to-Value (CLTV)  \
# 0                 I                                      73
# ...

# %%
df_final_cph.isna().sum()
# Out:
# Loan_ID                                         0
# Credit Score                                    0
# First Payment Date                              0
# Maturity Date                                   0
# Occupancy Status                                0
# Original Combined Loan-to-Value (CLTV)          0
# Original Debt-to-Income (DTI) Ratio             0
# Original UPB                                    0
# Original Loan Term                              0
# Monthly Reporting Period                        0
# Current Actual UPB                              0
# Current Loan Delinquency Status                 0
# Loan Age                                        0
# Current Interest Rate                           0
# Estimated Loan-to-Value (ELTV)            2745896
# dtype: int64

# %%
df_final_cph.shape
# Out:
# (23248344, 15)

# %%
# Save the DataFrame to a CSV file
df_final_cph.to_csv(
    'final_cph_data.csv', 
    index=False,               # CRITICAL: Do NOT save the pandas row index as a column
    encoding='utf-8'           # Standard encoding for compatibility
)

print("File saved successfully as 'final_cph_data.csv' in the current directory. ✅")
# Out:
# File saved successfully as 'final_cph_data.csv' in the current directory. ✅
